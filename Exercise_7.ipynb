# %% [markdown]
# <a href="https://colab.research.google.com/github/DanicaGuarino/CPE031-VDA-CPE21S4/blob/main/Exercise_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd
data = {
    'apples': [3, 2, 0, 1],
    'oranges': [0, 3, 7, 2]
}
purchases = pd.DataFrame(data)
purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %% [markdown]
# #**DataFrame Index**

# %%
purchases = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])
purchases
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %% [markdown]
# #**Locate - locate specific reecord**

# %%
purchases.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %% [markdown]
# #**Importing DataFrame to csv or excel file**

# %%
purchases.to_csv('fruits.csv')

# %% [markdown]
# #**Reading Data from csv**

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
df = pd.read_csv('fruits.csv')
purchases = pd.DataFrame(data)
print(purchases)
# Out:
#      <input type="file" id="files-05118e15-cb53-4eff-ae24-b8bfc528f635" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05118e15-cb53-4eff-ae24-b8bfc528f635">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #**Loading the data from excel file into DataFrame**

# %%
#Loading tha data from excel file

data = pd.read_excel("fruits.xlsx")
purchases = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-8974e1362db2> in <cell line: 3>()
#       1 #Loading tha data from excel file
#       2
# ----> 3 data = pd.read_excel("fruits.xlsx")
#       4 purchases = pd.DataFrame(data)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %% [markdown]
# #**Exploring the data of a DataFrame**

# %%
data=pd.read_excel("fruits.xlxs")
purchases=pd.DataFrame(data)
purchases.head()
shape=purchases.shape #will return a tuple containing rows and columns
shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-b591a8df0aa0> in <cell line: 1>()
# ----> 1 data=pd.read_excel("fruits.xlxs")
#       2 purchases=pd.DataFrame(data)
#       3 purchases.head()
#       4 shape=purchases.shape #will return a tuple containing rows and columns
#       5 shape
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %% [markdown]
# #**DataFrame.head(n)**

# %%
data.head(10)

# %% [markdown]
# #**DataFrame.tail(n)**

# %%
data.tail(3)

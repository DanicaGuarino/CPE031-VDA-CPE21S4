# %% [markdown]
# <a href="https://colab.research.google.com/github/DanicaGuarino/CPE031-VDA-CPE21S4/blob/main/Exercise_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import numpy as np
import matplotlib.pyplot as plt

#Generate data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

#Calculate the slope and y-intercept of the regression line
slope, intercept = np.polyfit(x, y, 1)

#Calculate the predicted values of y using the regression line equation
y_pred = slope * x + intercept

#Plot the data points and the regression line
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2,2,100)
y= x**2

fig = plt.figure(figsize=(10,5))
plt.plot (x,y)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt


# Given data points
x = np.array([0.50, 1.00, 1.30, 1.60, 2.20, 2.50, 3.10, 3.90, 4.40]).reshape(-1, 1)
y = np.array([1.90, 1.50, 1.20, 1.00, 0.78, 0.65, 0.46, 0.30, 0.23])

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='blue', label='Data Points')
plt.plot(x, y_pred, color='red', label='Linear Model')
plt.title("Linear Regression Model")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid()
plt.show()

print(f"Slope: {slope}")
print(f"Intercept: {intercept}")
# Out:
# Slope: -0.40558099147458176
# Intercept: 1.8149344805809917

# %% [markdown]
# **INTERPRETATION**
#
# The graph shows that as x increases, y decreases at a consistent rate. It implies that there is a steady reduction in y as x grows.
